# %%
import json

logs = """3073.702 Script @/Users/harshitsharma/Library/Application Support/factorio/temp/currently-playing/script/actions/player_inventory_transfers.lua:217: {"tick":57725,"selected_entity":{"name":"stone-furnace","type":"furnace","x":"-20.0","y":"39.0","valid":true},"cursor":{"item":"coal","count":50},"player":{"inventory_snapshot":{"iron-chest":2,"transport-belt":103,"inserter":4,"small-electric-pole":59,"pipe":81,"electric-mining-drill":4,"wood":152,"coal":137,"stone":317,"iron-plate":106,"copper-plate":65,"iron-gear-wheel":79,"electronic-circuit":145}}}
3073.702 Script @/Users/harshitsharma/Library/Application Support/factorio/temp/currently-playing/script/actions/player_inventory_transfers.lua:218: ########################
3074.302 Script @/Users/harshitsharma/Library/Application Support/factorio/temp/currently-playing/script/actions/player_inventory_transfers.lua:196: DEBUG: selected_entity type: table
3074.302 Script @/Users/harshitsharma/Library/Application Support/factorio/temp/currently-playing/script/actions/player_inventory_transfers.lua:197: DEBUG: selected_entity valid: true
3074.302 Script @/Users/harshitsharma/Library/Application Support/factorio/temp/currently-playing/script/actions/player_inventory_transfers.lua:198: DEBUG: selected_entity name: burner-mining-drill
3074.303 Script @/Users/harshitsharma/Library/Application Support/factorio/temp/currently-playing/script/actions/player_inventory_transfers.lua:217: {"tick":57742,"selected_entity":{"name":"burner-mining-drill","type":"mining-drill","x":"-22.0","y":"41.0","valid":true},"cursor":{"item":"coal","count":50},"player":{"inventory_snapshot":{"iron-chest":2,"transport-belt":103,"inserter":4,"small-electric-pole":59,"pipe":81,"electric-mining-drill":4,"wood":152,"coal":112,"stone":317,"iron-plate":106,"copper-plate":65,"iron-gear-wheel":79,"electronic-circuit":145}}}""".split("\n")

script = "Script @/Users/harshitsharma/Library/Application Support/factorio/temp/currently-playing/script/actions/player_inventory_transfers.lua"

with open("./file.log", "r") as f:
    logs = f.read().split("\n")

logs = [item for item in logs if script in item]

# %%
logs[:10]
# Out:
# ['5391.967 Script @/Users/harshitsharma/Library/Application Support/factorio/temp/currently-playing/script/actions/player_inventory_transfers.lua:212: {"tick":1045,"selected_entity":{"name":"burner-mining-drill","type":"mining-drill","x":"-22.0","y":"29.0","valid":true,"inventory_contents":{}},"cursor":{"coal":27},"player":{"inventory_snapshot":{"stone-furnace":5,"wood":1,"stone":2,"iron-plate":2,"iron-gear-wheel":3}}}',
#  '5391.967 Script @/Users/harshitsharma/Library/Application Support/factorio/temp/currently-playing/script/actions/player_inventory_transfers.lua:212: {"tick":1046,"selected_entity":{"name":"burner-mining-drill","type":"mining-drill","x":"-22.0","y":"29.0","valid":true,"inventory_contents":{}},"cursor":{"coal":26},"player":{"inventory_snapshot":{"stone-furnace":5,"wood":1,"stone":2,"iron-plate":2,"iron-gear-wheel":3}}}',
# ...

# %%
logs = [json.loads(item.split(": ")[-1]) for item in logs]

# %%
logs[:10]
# Out:
# [{'tick': 1045,
#   'selected_entity': {'name': 'burner-mining-drill',
#    'type': 'mining-drill',
#    'x': '-22.0',
#    'y': '29.0',
#    'valid': True,
#    'inventory_contents': {}},
#   'cursor': {'coal': 27},
#   'player': {'inventory_snapshot': {'stone-furnace': 5,
#     'wood': 1,
#     'stone': 2,
#     'iron-plate': 2,
#     'iron-gear-wheel': 3}}},
#  {'tick': 1046,
#   'selected_entity': {'name': 'burner-mining-drill',
#    'type': 'mining-drill',
#    'x': '-22.0',
#    'y': '29.0',
#    'valid': True,
#    'inventory_contents': {}},
#   'cursor': {'coal': 26},
#   'player': {'inventory_snapshot': {'stone-furnace': 5,
#     'wood': 1,
#     'stone': 2,
#     'iron-plate': 2,
#     'iron-gear-wheel': 3}}},
#  {'tick': 1048,
#   'selected_entity': {'name': 'stone-furnace',
#    'type': 'furnace',
#    'x': '-20.0',
#    'y': '29.0',
#    'valid': True,
#    'inventory_contents': {'coal': 1}},
#   'cursor': {'coal': 25},
# ...

# %%
total = []

for log in logs:
    log_total = {}
    for k, v in log["selected_entity"]["inventory_contents"]:
        log_total[k]=log_total[v]
    for k, v in log["cursor"]:
        log_total[k]=log_total[v]
    for k, v in log["player"]["inventory_snapshot"]:
        log_total[k]=log_total[v]
