# %%
import pandas as pd
import json

df = pd.read_json("/Users/harshitsharma/Code/exp/factorio-data-collector/factorio_replays/replay-logs/craft_item_collated.jsonl", lines=True)

df.head()

df.tail()

df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   t                176 non-null    int64
#  1   p                176 non-null    int64
#  2   ev               176 non-null    object
#  3   action           176 non-null    object
#  4   recipe           176 non-null    object
#  5   start_tick       176 non-null    int64
#  6   end_tick         176 non-null    int64
#  7   duration_ticks   176 non-null    int64
#  8   total_queued     176 non-null    int64
#  9   total_crafted    176 non-null    int64
#  10  total_cancelled  176 non-null    int64
#  11  x                176 non-null    float64
#  12  y                176 non-null    float64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 18.0+ KB
#                    t      p     start_tick       end_tick  duration_ticks  \
# ...

# %%
df.total_cancelled.value_counts()
# Out:
# total_cancelled
# 0      156
# 5        3
# 10       2
# 3        2
# 1        2
# 32       1
# 7        1
# 15       1
# 483      1
# 25       1
# 12       1
# 33       1
# 976      1
# 691      1
# 321      1
# 4        1
# Name: count, dtype: int64

# %%
import pandas as pd
import json

df = pd.read_json("/Users/harshitsharma/Code/exp/factorio-data-collector/factorio_replays/replay-logs/move_to_collated.jsonl", lines=True)

df.head()

df.tail()

df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3991 entries, 0 to 3990
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   t               3991 non-null   int64
#  1   p               3991 non-null   int64
#  2   ev              3991 non-null   object
#  3   x               3991 non-null   float64
#  4   y               3991 non-null   float64
#  5   action          3991 non-null   object
#  6   direction       3991 non-null   object
#  7   start_tick      3991 non-null   int64
#  8   end_tick        3991 non-null   int64
#  9   duration_ticks  3991 non-null   int64
#  10  start_x         3991 non-null   float64
#  11  start_y         3991 non-null   float64
#  12  end_x           3991 non-null   float64
#  13  end_y           3991 non-null   float64
#  14  distance        3991 non-null   float64
# dtypes: float64(7), int64(5), object(3)
# memory usage: 467.8+ KB
# ...

# %%
import pandas as pd
import json

df = pd.read_json("/Users/harshitsharma/Code/exp/factorio-data-collector/factorio_replays/replay-logs/insert_item.jsonl", lines=True)

display(df.head())

display(df.tail())

display(df.info())

df.describe()
# Out:
#      t  p                                ev       action     transfer_type  \
# 0  553  1  on_player_main_inventory_changed  insert_item  inventory_change
# 1  553  1  on_player_main_inventory_changed  insert_item  inventory_change
# 2  553  1  on_player_main_inventory_changed  insert_item  inventory_change
# 3  553  1  on_player_main_inventory_changed  insert_item  inventory_change
# 4  553  1  on_player_main_inventory_changed  insert_item  inventory_change
#
#                   item  count  direction    x     y entity  is_split  \
# 0  burner-mining-drill    1.0  to_player -7.9 -21.0    NaN       NaN
# 1        stone-furnace    1.0  to_player -7.9 -21.0    NaN       NaN
# 2                 wood    1.0  to_player -7.9 -21.0    NaN       NaN
# 3                stone   47.0  to_player -7.9 -21.0    NaN       NaN
# 4                 coal   27.0  to_player -7.9 -21.0    NaN       NaN
#
#    from_player target_entity
# 0          NaN           NaN
# 1          NaN           NaN
# ...

# %%
# Out:
# transfer_type
# inventory_change             11789
# fast_transfer_from_entity     2202
# gui_transfer                   514
# fast_transfer_to_entity        482
# z_key_insert                    18
# drop_to_ground                  11
# Name: count, dtype: int64

# %%
import pandas as pd
import json

df = pd.read_json("/Users/harshitsharma/Code/exp/factorio-data-collector/factorio_replays/replay-logs/insert_item_collated.jsonl", lines=True)

display(df.head())

display(df.tail())

display(df.info())

df.describe()
# Out:
#      t  p                                ev                action  \
# 0  617  1  on_player_main_inventory_changed  insert_item_collated
# 1  617  1  on_player_main_inventory_changed  insert_item_collated
# 2  617  1  on_player_main_inventory_changed  insert_item_collated
# 3  617  1  on_player_main_inventory_changed  insert_item_collated
# 4  617  1  on_player_main_inventory_changed  insert_item_collated
#
#       transfer_type                 item  count  direction     x     y entity  \
# 0  inventory_change  burner-mining-drill    1.0  to_player -14.6 -14.3    NaN
# 1  inventory_change        stone-furnace    1.0  to_player -14.6 -14.3    NaN
# 2  inventory_change                 wood    1.0  to_player -14.6 -14.3    NaN
# 3  inventory_change                 coal   27.0  to_player -14.6 -14.3    NaN
# 4  inventory_change                stone    2.0  to_player -14.6 -14.3    NaN
#
#    is_split  from_player target_entity
# 0       NaN          NaN           NaN
# ...

# %%
df.transfer_type.value_counts()
# Out:
# transfer_type
# inventory_change             6681
# fast_transfer_from_entity    2138
# fast_transfer_to_entity       300
# gui_transfer                  236
# z_key_insert                  101
# z_key_extract                  60
# drop_to_ground                 11
# Name: count, dtype: int64

# %%
df.head(50)
# Out:
#        t  p                                ev       action  \
# 0    553  1  on_player_main_inventory_changed  insert_item
# 1    553  1  on_player_main_inventory_changed  insert_item
# 2    553  1  on_player_main_inventory_changed  insert_item
# 3    553  1  on_player_main_inventory_changed  insert_item
# 4    553  1  on_player_main_inventory_changed  insert_item
# 5    617  1  on_player_main_inventory_changed  insert_item
# 6    647  1  on_player_main_inventory_changed  insert_item
# 7    651  1        on_player_fast_transferred  insert_item
# 8    651  1  on_player_main_inventory_changed  insert_item
# 9    678  1  on_player_main_inventory_changed  insert_item
# 10   699  1        on_player_fast_transferred  insert_item
# 11   699  1  on_player_main_inventory_changed  insert_item
# 12   709  1  on_player_main_inventory_changed  insert_item
# 13   712  1        on_player_fast_transferred  insert_item
# 14   712  1  on_player_main_inventory_changed  insert_item
# ...

# %%
import pandas as pd
import json

df = pd.read_json("/Users/harshitsharma/Code/exp/factorio-data-collector/factorio_replays/replay-logs/player_inventory_transfers.jsonl", lines=True)

display(df.head())

display(df.tail())

df.info()
# Out:
#      t  p                          ev        action     event_name  \
# 0  651  1  player_inventory_transfers  extract_item  fast_transfer
# 1  699  1  player_inventory_transfers  extract_item  fast_transfer
# 2  712  1  player_inventory_transfers  extract_item  fast_transfer
# 3  716  1  player_inventory_transfers  extract_item  fast_transfer
# 4  727  1  player_inventory_transfers  extract_item  fast_transfer
#
#                                 entity  entity_x  entity_y  \
# 0  crash-site-spaceship-wreck-medium-1     -17.6      -6.9
# 1  crash-site-spaceship-wreck-medium-2     -27.4      -5.5
# 2     crash-site-spaceship-wreck-big-2     -23.6      -2.2
# 3     crash-site-spaceship-wreck-big-2     -23.6      -2.2
# 4     crash-site-spaceship-wreck-big-1     -25.8       0.1
#
#                                   items  no_op     x     y
# 0  [{'item': 'iron-plate', 'count': 2}]  False -18.1 -10.8
# 1  [{'item': 'iron-plate', 'count': 1}]  False -20.9  -4.8
# ...

# %%
df.no_op.value_counts()
# Out:
# no_op
# False    2397
# True      548
# Name: count, dtype: int64
